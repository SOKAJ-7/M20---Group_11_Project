# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
#Import our data
songs_df = pd.read_csv('SpotifyFeatures.csv')

# %%
#Create subsetted dataframe for our genre
genre_df = songs_df[songs_df['genre'] == 'Indie']
genre_df.head()
# Out:
#        genre  artist_name                                    track_name  \
# 92824  Indie       Halsey                                    Without Me
# 92825  Indie     YUNGBLUD  11 Minutes (with Halsey feat. Travis Barker)
# 92826  Indie    Grouplove                                   Tongue Tied
# 92827  Indie  The Killers                                Mr. Brightside
# 92828  Indie   Lord Huron                              The Night We Met
#
#                      track_id  popularity  acousticness  danceability  \
# 92824  5p7ujcrUXASCNwRaWNHR1C          97       0.29700         0.752
# 92825  4mGdjNMo0RonTlOEb7cYg4          87       0.01160         0.464
# 92826  0GO8y8jQk1PkHzS31d699N          80       0.00847         0.560
# 92827  7oK9VyNzrYvRFo7nQEYkWN          80       0.00108         0.330
# 92828  0QZ5yyl6B6utIWkxeBDxQN          78       0.96800         0.441
#
#        duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 92824       201661   0.488          0.000009  F#    0.0936    -7.050  Major
# 92825       239507   0.852          0.000000   B    0.1080    -3.804  Major
# 92826       218013   0.936          0.000000  D#    0.1610    -5.835  Major
# 92827       222587   0.936          0.000000  C#    0.0926    -3.660  Major
# 92828       208227   0.379          0.262000   D    0.6390    -9.545  Major
#
#        speechiness    tempo time_signature  valence
# 92824       0.0705  136.041            4/4    0.533
# 92825       0.0670  160.075            4/4    0.233
# 92826       0.0439  112.960            4/4    0.371
# 92827       0.0917  148.112            4/4    0.234
# 92828       0.0449  174.118            3/4    0.105

# %%
#Start prepping data for our model
#Drop columns not relevant to the model
genre_df = genre_df.drop(columns=['genre','artist_name','track_name','track_id','time_signature'])

genre_df.head()
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 92824          97       0.29700         0.752       201661   0.488
# 92825          87       0.01160         0.464       239507   0.852
# 92826          80       0.00847         0.560       218013   0.936
# 92827          80       0.00108         0.330       222587   0.936
# 92828          78       0.96800         0.441       208227   0.379
#
#        instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# 92824          0.000009  F#    0.0936    -7.050  Major       0.0705  136.041
# 92825          0.000000   B    0.1080    -3.804  Major       0.0670  160.075
# 92826          0.000000  D#    0.1610    -5.835  Major       0.0439  112.960
# 92827          0.000000  C#    0.0926    -3.660  Major       0.0917  148.112
# 92828          0.262000   D    0.6390    -9.545  Major       0.0449  174.118
#
#        valence
# 92824    0.533
# 92825    0.233
# 92826    0.371
# 92827    0.234
# 92828    0.105

# %%
#Encode our categorical variables
genre_df_encoded = pd.get_dummies(genre_df, columns = ['mode','key'])
genre_df_encoded
# Out:
#         popularity  acousticness  danceability  duration_ms  energy  \
# 92824           97       0.29700         0.752       201661   0.488
# 92825           87       0.01160         0.464       239507   0.852
# 92826           80       0.00847         0.560       218013   0.936
# 92827           80       0.00108         0.330       222587   0.936
# 92828           78       0.96800         0.441       208227   0.379
# ...            ...           ...           ...          ...     ...
# 145424          45       0.02980         0.528       232528   0.874
# 145425          43       0.89100         0.551       181773   0.305
# 145426          52       0.53300         0.605       200240   0.731
# 145427          48       0.03140         0.599       231111   0.870
# 145428          44       0.51400         0.623       251400   0.504
#
#         instrumentalness  liveness  loudness  speechiness    tempo  ...  \
# 92824           0.000009    0.0936    -7.050       0.0705  136.041  ...
# 92825           0.000000    0.1080    -3.804       0.0670  160.075  ...
# 92826           0.000000    0.1610    -5.835       0.0439  112.960  ...
# 92827           0.000000    0.0926    -3.660       0.0917  148.112  ...
# 92828           0.262000    0.6390    -9.545       0.0449  174.118  ...
# ...                  ...       ...       ...          ...      ...  ...
# 145424          0.000022    0.1800    -3.396       0.0334  123.503  ...
# 145425          0.000001    0.2580   -11.360       0.0321  145.811  ...
# 145426          0.000951    0.1110    -4.683       0.0349   92.483  ...
# 145427          0.000000    0.2610    -4.394       0.1050   80.949  ...
# 145428          0.793000    0.1370   -12.285       0.0305  100.025  ...
#
#         key_B  key_C  key_C#  key_D  key_D#  key_E  key_F  key_F#  key_G  \
# 92824       0      0       0      0       0      0      0       1      0
# 92825       1      0       0      0       0      0      0       0      0
# 92826       0      0       0      0       1      0      0       0      0
# 92827       0      0       1      0       0      0      0       0      0
# 92828       0      0       0      1       0      0      0       0      0
# ...       ...    ...     ...    ...     ...    ...    ...     ...    ...
# 145424      1      0       0      0       0      0      0       0      0
# 145425      1      0       0      0       0      0      0       0      0
# 145426      0      0       0      1       0      0      0       0      0
# 145427      0      0       0      0       0      0      0       0      0
# 145428      0      1       0      0       0      0      0       0      0
#
#         key_G#
# 92824        0
# 92825        0
# 92826        0
# 92827        0
# 92828        0
# ...        ...
# 145424       0
# 145425       0
# 145426       0
# 145427       1
# 145428       0
#
# [9543 rows x 25 columns]

# %%
#Split our data into target and feature variables
X = genre_df_encoded.drop(columns=['popularity']).values
y= genre_df_encoded['popularity'].values

# %%
#Create Test/Train Splits
from sklearn.model_selection import train_test_split
X_test, X_train, y_test, y_train = train_test_split(X, y, random_state=1)

X_train
# Out:
# array([[2.11000e-02, 4.15000e-01, 1.56987e+05, ..., 0.00000e+00,
#         1.00000e+00, 0.00000e+00],
#        [5.20000e-01, 4.06000e-01, 2.58531e+05, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [1.45000e-02, 6.94000e-01, 2.58000e+05, ..., 1.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        ...,
#        [9.67000e-01, 4.92000e-01, 1.96760e+05, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [1.51000e-01, 5.98000e-01, 2.02111e+05, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [1.47000e-01, 5.25000e-01, 1.92028e+05, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00]])

# %%
#Create and fit RandomForestRegression Model
rr= RandomForestRegressor(n_estimators = 50, random_state = 0)

rr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %%
#Create predictions
y_pred = rr.predict(X_test)
print(y_pred)
# Out:
# [51.48 55.72 55.94 ... 56.06 53.86 55.36]

# %%
#Check R-squared value
r_square = rr.score(X,y)
r_square
# Out:
# 0.20959584481196591

# %%
#Check Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 54.47428906897676

# %%
#Check Root Mean Squared Error
rmse = np.sqrt(mse)
rmse
# Out:
# 7.380669960713374

# %%
#Mean Absolute error
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 5.783255554003073

# %%
#Check feature importance
feat_imp = rr.feature_importances_
pd.DataFrame(feat_imp)
# Out:
#            0
# 0   0.088011
# 1   0.098696
# 2   0.096703
# 3   0.087261
# 4   0.086342
# 5   0.085900
# 6   0.094032
# 7   0.083374
# 8   0.102216
# 9   0.088004
# 10  0.005518
# 11  0.006030
# 12  0.007650
# 13  0.004639
# 14  0.004976
# 15  0.007964
# 16  0.004111
# 17  0.006274
# 18  0.001645
# 19  0.006093
# 20  0.011510
# 21  0.010003
# 22  0.006911
# 23  0.006137

# %%
rr.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 50,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}
