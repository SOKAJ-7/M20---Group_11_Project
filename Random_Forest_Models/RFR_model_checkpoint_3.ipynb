# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
#Import our data
songs_df = pd.read_csv('SpotifyFeatures.csv')

# %%
#Create subsetted dataframe for our genre
genre_df = songs_df[songs_df['genre'] == 'Indie']
genre_df.head()
# Out:
#        genre  artist_name                                    track_name  \
# 92824  Indie       Halsey                                    Without Me
# 92825  Indie     YUNGBLUD  11 Minutes (with Halsey feat. Travis Barker)
# 92826  Indie    Grouplove                                   Tongue Tied
# 92827  Indie  The Killers                                Mr. Brightside
# 92828  Indie   Lord Huron                              The Night We Met
#
#                      track_id  popularity  acousticness  danceability  \
# 92824  5p7ujcrUXASCNwRaWNHR1C          97       0.29700         0.752
# 92825  4mGdjNMo0RonTlOEb7cYg4          87       0.01160         0.464
# 92826  0GO8y8jQk1PkHzS31d699N          80       0.00847         0.560
# 92827  7oK9VyNzrYvRFo7nQEYkWN          80       0.00108         0.330
# 92828  0QZ5yyl6B6utIWkxeBDxQN          78       0.96800         0.441
#
#        duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 92824       201661   0.488          0.000009  F#    0.0936    -7.050  Major
# 92825       239507   0.852          0.000000   B    0.1080    -3.804  Major
# 92826       218013   0.936          0.000000  D#    0.1610    -5.835  Major
# 92827       222587   0.936          0.000000  C#    0.0926    -3.660  Major
# 92828       208227   0.379          0.262000   D    0.6390    -9.545  Major
#
#        speechiness    tempo time_signature  valence
# 92824       0.0705  136.041            4/4    0.533
# 92825       0.0670  160.075            4/4    0.233
# 92826       0.0439  112.960            4/4    0.371
# 92827       0.0917  148.112            4/4    0.234
# 92828       0.0449  174.118            3/4    0.105

# %%
#Start prepping data for our model
#Drop columns not relevant to the model
genre_df = genre_df.drop(columns=['genre','artist_name','track_name','track_id','time_signature','liveness','acousticness','speechiness'])

genre_df.head()
# Out:
#        popularity  danceability  duration_ms  energy  instrumentalness key  \
# 92824          97         0.752       201661   0.488          0.000009  F#
# 92825          87         0.464       239507   0.852          0.000000   B
# 92826          80         0.560       218013   0.936          0.000000  D#
# 92827          80         0.330       222587   0.936          0.000000  C#
# 92828          78         0.441       208227   0.379          0.262000   D
#
#        loudness   mode    tempo  valence
# 92824    -7.050  Major  136.041    0.533
# 92825    -3.804  Major  160.075    0.233
# 92826    -5.835  Major  112.960    0.371
# 92827    -3.660  Major  148.112    0.234
# 92828    -9.545  Major  174.118    0.105

# %%
#Encode our categorical variables
genre_df_encoded = pd.get_dummies(genre_df, columns = ['mode','key'])
genre_df_encoded
# Out:
#         popularity  danceability  duration_ms  energy  instrumentalness  \
# 92824           97         0.752       201661   0.488          0.000009
# 92825           87         0.464       239507   0.852          0.000000
# 92826           80         0.560       218013   0.936          0.000000
# 92827           80         0.330       222587   0.936          0.000000
# 92828           78         0.441       208227   0.379          0.262000
# ...            ...           ...          ...     ...               ...
# 145424          45         0.528       232528   0.874          0.000022
# 145425          43         0.551       181773   0.305          0.000001
# 145426          52         0.605       200240   0.731          0.000951
# 145427          48         0.599       231111   0.870          0.000000
# 145428          44         0.623       251400   0.504          0.793000
#
#         loudness    tempo  valence  mode_Major  mode_Minor  ...  key_B  key_C  \
# 92824     -7.050  136.041    0.533           1           0  ...      0      0
# 92825     -3.804  160.075    0.233           1           0  ...      1      0
# 92826     -5.835  112.960    0.371           1           0  ...      0      0
# 92827     -3.660  148.112    0.234           1           0  ...      0      0
# 92828     -9.545  174.118    0.105           1           0  ...      0      0
# ...          ...      ...      ...         ...         ...  ...    ...    ...
# 145424    -3.396  123.503    0.886           0           1  ...      1      0
# 145425   -11.360  145.811    0.420           1           0  ...      1      0
# 145426    -4.683   92.483    0.412           1           0  ...      0      0
# 145427    -4.394   80.949    0.611           1           0  ...      0      0
# 145428   -12.285  100.025    0.444           1           0  ...      0      1
#
#         key_C#  key_D  key_D#  key_E  key_F  key_F#  key_G  key_G#
# 92824        0      0       0      0      0       1      0       0
# 92825        0      0       0      0      0       0      0       0
# 92826        0      0       1      0      0       0      0       0
# 92827        1      0       0      0      0       0      0       0
# 92828        0      1       0      0      0       0      0       0
# ...        ...    ...     ...    ...    ...     ...    ...     ...
# 145424       0      0       0      0      0       0      0       0
# 145425       0      0       0      0      0       0      0       0
# 145426       0      1       0      0      0       0      0       0
# 145427       0      0       0      0      0       0      0       1
# 145428       0      0       0      0      0       0      0       0
#
# [9543 rows x 22 columns]

# %%
#Split our data into target and feature variables
X = genre_df_encoded.drop(columns=['popularity']).values
y= genre_df_encoded['popularity'].values

# %%
#Create Test/Train Splits
from sklearn.model_selection import train_test_split
X_test, X_train, y_test, y_train = train_test_split(X, y, random_state=1)

X_train
# Out:
# array([[4.15000e-01, 1.56987e+05, 7.13000e-01, ..., 0.00000e+00,
#         1.00000e+00, 0.00000e+00],
#        [4.06000e-01, 2.58531e+05, 4.49000e-01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [6.94000e-01, 2.58000e+05, 8.28000e-01, ..., 1.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        ...,
#        [4.92000e-01, 1.96760e+05, 1.65000e-01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [5.98000e-01, 2.02111e+05, 6.48000e-01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [5.25000e-01, 1.92028e+05, 6.35000e-01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00]])

# %%
#Create and fit RandomForestRegression Model
rr= RandomForestRegressor(random_state = 0)

# %%
#Set up parameters
n_estimators = [5,10,50,100,250,500]
max_features = ['auto','sqrt']
max_depth = [2,3,4]
min_samples_split = [2,5,10]
min_samples_leaf = [1,2,3]
bootstrap = [True,False]

# %%
#Optimize parameters
parameters = {
    "n_estimators": n_estimators,
    "max_depth" : max_features,
    "max_depth" : max_depth,
    "min_samples_split" : min_samples_split,
    "min_samples_leaf" : min_samples_leaf,
    "bootstrap" : bootstrap
    }
cv = GridSearchCV(rr,parameters,cv=5)
cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=0),
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 3, 4],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [5, 10, 50, 100, 250, 500]})

# %%
print(f'The best parameters are {cv.best_params_}')
# Out:
# The best parameters are {'bootstrap': True, 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}

# %%
#Fit the model with best parameters
rr = RandomForestRegressor(n_estimators = cv.best_params_['n_estimators'], 
                           max_depth = cv.best_params_['max_depth'], 
                           min_samples_split = cv.best_params_['min_samples_split'],
                           min_samples_leaf =  cv.best_params_['min_samples_leaf'],
                           bootstrap = cv.best_params_['bootstrap'],
                           random_state = 0)
rr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, min_samples_leaf=3, n_estimators=500,
#                       random_state=0)

# %%
#Create predictions
y_pred = rr.predict(X_test)
print(y_pred)
# Out:
# [54.33204468 54.21916441 54.79926564 ... 55.04620869 55.14464108
#  55.22299164]

# %%
#Check R-squared value
r_square = rr.score(X,y)
r_square
# Out:
# 0.04986144104167656

# %%
#Check Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 52.680148942159114

# %%
#Check Root Mean Squared Error
rmse = np.sqrt(mse)
rmse
# Out:
# 7.258109185053578

# %%
#Mean Absolute error
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 5.702081234998351

# %%
#Check feature importance
feat_imp = rr.feature_importances_
pd.DataFrame(feat_imp)
# Out:
#            0
# 0   0.157072
# 1   0.107536
# 2   0.138493
# 3   0.244038
# 4   0.109658
# 5   0.115159
# 6   0.072244
# 7   0.002661
# 8   0.003217
# 9   0.001325
# 10  0.001443
# 11  0.003993
# 12  0.000791
# 13  0.000972
# 14  0.002817
# 15  0.000117
# 16  0.001551
# 17  0.010748
# 18  0.017644
# 19  0.003151
# 20  0.005370

# %%
rr.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 500,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}
