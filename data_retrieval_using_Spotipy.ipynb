# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from config import cid, secret
import pandas as pd
import timeit

auth_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# In a separate .py file, set your own credentials (CID and secret). I think using the Web API requires a paid subscription to Spotify. Log into developer.spotify.com, navigate to Dashboards and create an app (give an app name, description, accept the ToS) to generate your credentials.

# %% [markdown]
# #### Example list of genres we're interested in:

# %%
genre_list = [
    'soundtrack','indie','jazz','pop','electronic','folk','hip-hop','rock','alternative','classical','rap','world',
    'soul','blues','R&B','reggae','ska','dance','country','opera'
]
print(f'We have {len(genre_list)} genres.')
# Out:
# We have 20 genres.

# %% [markdown]
# ## Get the track/artist/album data

# %%
# Start timer
start = timeit.default_timer()

# Set empty lists for each feature
track_name = []
popularity = []
track_id = []
artist_name = []
artist_id = []
artist_genre = []
album_name = []
album_id = []
release_date = []
followers = []

# Loop through the genre list and use each genre as a parameter when running the track-type search 
for genre in genre_list:
    # save track-type search in variable
    track_looped = sp.search(q='genre:'+genre, type='track',limit=3) # set limit to number of songs to grab per genre
    # loop through saved search results, append according to their index/position within the nested levels of dictionaries/lists
    for i, t in enumerate(track_looped['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        album_name.append(t['album']['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        artist_genre.append(genre)

# Using the album names collected from the first search, conduct album-type search to retrieve release date (only found with album search)
for album in album_name:
    album_looped = sp.search(q='album:'+album, type='album',limit=1)
    # similarly, append appropriate metrics found within the nests
    for i, a in enumerate(album_looped['albums']['items']):
        album_id.append(a['id'])
        release_date.append(a['release_date'])

# Lastly, using the artist names collected from first search, conduct artist-type search to retrieve number of followers per artist (only found with artist search)
for name in artist_name: 
    artist_looped = sp.search(q='artist:'+name, type='artist',limit=1)
    for i, n in enumerate(artist_looped['artists']['items']):
        followers.append(n['followers']['total'])

stop = timeit.default_timer()
print(f'This took {stop - start} seconds to complete.')
# Out:
# This took 11.761856000000002 seconds to complete.

# %% [markdown]
# #### Checking total tracks gathered:

# %%
print(f'Total number of track IDs: {len(track_id)}')
# Out:
# Total number of track IDs: 60

# %% [markdown]
# #### Load the lists as a DataFrame:

# %%
df_tracks = pd.DataFrame({
    'genre':artist_genre,
    'artist_name':artist_name, 
    'artist_id':artist_id,
    'followers':followers,
    'track_name':track_name, 
    'track_id':track_id,
    'popularity':popularity,
    'album_name':album_name,
    'album_id':album_id,
    'release_date':release_date
})
df_tracks.head()
# Out:
#         genre        artist_name               artist_id  followers  \
# 0  soundtrack           Toby Fox  57DlMWmbVIf2ssJ8QBpBau     711972
# 1  soundtrack  Michael Giacchino  4kLvhMAuCloLxoP1aVM7Lr     253169
# 2  soundtrack        Hans Zimmer  0YC192cP3KPCRWx8zr8MfZ    2924485
# 3       indie        The Walters  027TpXKGwdXP7iwbjUSpV8     324716
# 4       indie           Yot Club  6FugQjLquBF4JzATRN70bR     150080
#
#         track_name                track_id  popularity  \
# 0      Fallen Down  1jDMi92a9zNQuPD3uPMkla          77
# 1       The Batman  1NkI8DtCnjcWVCVLF0gB71          74
# 2  Cornfield Chase  6pWgRkpqVfxnj3WuIcJ7WP          78
# 3    I Love You So  4SqWKzw0CbA05TGszDgMlc          96
# 4           YKWIM?  2vWBUC9djv6BtiGlmKiQaH          88
#
#                                           album_name                album_id  \
# 0                               UNDERTALE Soundtrack  2M2Ae2SvZe3fmzUtlVOV5Z
# 1    The Batman (Original Motion Picture Soundtrack)  18nTX27XXEYARGmWMTgD19
# 2  Interstellar (Original Motion Picture Soundtra...  3B61kSKTxlY36cYgzvf3cP
# 3                                      I Love You So  7ucm85tRsWk6EyVHaYAxe9
# 4                                            Bipolar  60jUlxAOAcsiQUEW0XLroT
#
#   release_date
# 0   2015-09-15
# 1   2022-02-24
# 2   2014-11-18
# 3   2014-11-28
# 4   2019-05-31

# %%
group_track_artist_id = df_tracks.sort_values(by=['artist_name','track_name'])
group_track_artist_id
# concatenate artist_id and track_id and assess unique values
# one to many relationship between track and genre
# store all songs in table PK=track_id, another table with just genre, artist table
# if spotify classifies multiple genres for a song, it could 
# aggregate popular songs to genres they're associated to
# Out:
#           genre            artist_name               artist_id  followers  \
# 37         soul                  Adele  4dpARuHxo51G3z768sgnrY   36021792
# 38         soul                  Adele  4dpARuHxo51G3z768sgnrY   36021792
# 59        opera         Andrea Bocelli  3EA9hVIzKfFiQI0Kikz2wo    2081771
# 5         indie         Arctic Monkeys  7Ln80lUS6He07XvHI8qqHH   14112457
# 23         rock         Arctic Monkeys  7Ln80lUS6He07XvHI8qqHH   14112457
# 46       reggae              Bad Bunny  4q3ewBCX7sLwd24euuV69X   45908897
# 45       reggae                Becky G  4obzFoKoKRHIphyHzJ35G3   11164712
# 53        dance                Becky G  4obzFoKoKRHIphyHzJ35G3   11164712
# 39        blues      Cage The Elephant  26T3LtbuGT1Fu9m0eRq5X3    2838652
# 41        blues      Cage The Elephant  26T3LtbuGT1Fu9m0eRq5X3    2838652
# 34        world            Cory Asbury  2gXmjQIxCO8lMnSncluZaU     361971
# 14   electronic               DJ Snake  540vIaP2JwjQb9dm3aArA4    7732850
# 13   electronic               DJ Snake  540vIaP2JwjQb9dm3aArA4    7732850
# 10          pop               Doja Cat  5cj0lLjcoR7YOSnhnX0Po5   17169273
# 52        dance               Doja Cat  5cj0lLjcoR7YOSnhnX0Po5   17169273
# 9           pop               Doja Cat  5cj0lLjcoR7YOSnhnX0Po5   17169273
# 51        dance               Doja Cat  5cj0lLjcoR7YOSnhnX0Po5   17169273
# 19      hip-hop                Dolphin  2pktDyTJxrLJo7dL2qT1pA       4821
# 11          pop           Dove Cameron  2W8yFh0Ga6Yf3jiayVxwkE    3285109
# 20      hip-hop                  Drake  3TVXtAsR1Inumwj472S9r4   62232854
# 6          jazz     Earth, Wind & Fire  4QQgXkCYTt3BlENzhyNETg    3378956
# 28    classical             Erik Satie  459INk8vcC0ebEef82WjIK     644806
# 8          jazz             Etta James  0iOVhN3tnSvgDbcg25JoJb    1320104
# 26  alternative            Frank Ocean  2h93pZq0e7k5yf4dywlkpM    9184560
# 36         soul            Frank Ocean  2h93pZq0e7k5yf4dywlkpM    9184560
# 43          R&B            Frank Ocean  2h93pZq0e7k5yf4dywlkpM    9184560
# 24  alternative                  GAYLE  2VSHKHBTiXWplO8lxcnUC9     358857
# 32          rap                  Gunna  2hlmm7s2ICUX0LVIhVFlZQ    4132710
# 2    soundtrack            Hans Zimmer  0YC192cP3KPCRWx8zr8MfZ    2924485
# 33        world        Hillsong UNITED  74cb3MG0x0BOnYNW1uXYnM    3349124
# 35        world       Hillsong Worship  3SgHzT552wy2W8pNLaLk24    3780209
# 31          rap               Ice Cube  3Mcii5XWf6E0lrY3Uky4cA    5436116
# 21         rock        Imagine Dragons  53XhwfbYqKCa1cC15pYq2q   39106669
# 58        opera   Jean-Philippe Rameau  4JSWO1Pf2zV991fq64uAce      60333
# 29    classical  Johann Sebastian Bach  5aIqB5nVVvmFsvSdExz408    3594744
# 7          jazz         Johnny Griffin  52cM6vrM4MJ8g4H7Ibo5fZ      18079
# 56      country           Jordan Davis  77kULmXAQ6vWer7IIHdGzI     597050
# 57        opera            Josh Groban  6cXMpsP9x0SH4kFfMyVezF     777412
# 18      hip-hop            Kodak Black  46SHBwWsqBkxI7EeeBEQG7    7954622
# 30          rap            Kodak Black  46SHBwWsqBkxI7EeeBEQG7    7954622
# 15         folk             Lord Huron  6ltzsmQQbmdoHHbLZ4ZN25    1028398
# 27    classical       Ludovico Einaudi  2uFUBdaVGtyMqckSeCl0Qj    2661785
# 1    soundtrack      Michael Giacchino  4kLvhMAuCloLxoP1aVM7Lr     253169
# 54      country          Morgan Wallen  4oUHIQIBe0LHzYfvXNW4QM    3119413
# 55      country          Morgan Wallen  4oUHIQIBe0LHzYfvXNW4QM    3119413
# 42          R&B                    SZA  7tYKF4w9nC0nq9CsPZTHyP    7469051
# 12   electronic              Sohodolls  1KNXft7nnRQj82sENi7WGN      62908
# 48          ska                Sublime  0EdvGhlC1FkGItLOWQzG4J    2184835
# 50          ska                Sublime  0EdvGhlC1FkGItLOWQzG4J    2184835
# 47       reggae                  Tainy  0GM7qgcRCORpGnfcN2tCiB     830427
# 17         folk          The Lumineers  16oZKvXb6WkQlVAjwo2Wbg    4666628
# 25  alternative      The Neighbourhood  77SW9BnxLY8rJ0RciFqkHh    8523038
# 49          ska          The Offspring  5LfGQac0EIXyAN8aUwmNAQ    4603137
# 3         indie            The Walters  027TpXKGwdXP7iwbjUSpV8     324716
# 44          R&B             The Weeknd  1Xyo4u8uXC1ZmMpatF05PJ   43248780
# 40        blues      The White Stripes  4F84IBURUo98rz4r61KF70    2644343
# 0    soundtrack               Toby Fox  57DlMWmbVIf2ssJ8QBpBau     711972
# 16         folk              Vance Joy  10exVja0key0uqUkk6LJRT    2576326
# 22         rock                 Weezer  3jOstUTkEu2JkjvRdBA5Gu    2622314
# 4         indie               Yot Club  6FugQjLquBF4JzATRN70bR     150080
#
#                                            track_name                track_id  \
# 37                                         Easy On Me  0gplL1WMoJ6iYaPgMCL0gX
# 38                                          Oh My God  3Kkjo3cT83cw09VJyrLNwX
# 59                                     Con te partirò  7zrpoAJte9o12TzawqgdD0
# 5                                                 505  58ge6dfP91o9oXMzq3XkIS
# 23                                                505  58ge6dfP91o9oXMzq3XkIS
# 46                                           Yonaguni  2JPLbjOn0wPCngEot2STUS
# 45                                             MAMIII  1ri9ZUkBJVFUdgwzCnfcYs
# 53                                             MAMIII  1ri9ZUkBJVFUdgwzCnfcYs
# 39                                Cigarette Daydreams  2tznHmp70DxMyr2XhWLOW0
# 41                               Come a Little Closer  4sebUbjqbcgDSwG6PbSGI0
# 34                                      Reckless Love  0rH0mprtecH3grD9HFM5AD
# 14                                    Let Me Love You  0lYBSQXN6rCTvUZvg9S0lU
# 13                                      U Are My High  3S7A85bAWOd6ltk6r2ANOI
# 10                                       Need to Know  3Vi5XqYrmQgOYBajMWSvCi
# 52                                       Need to Know  3Vi5XqYrmQgOYBajMWSvCi
# 9                                               Woman  6Uj1ctrBOjOas8xZXGqKk4
# 51                                              Woman  6Uj1ctrBOjOas8xZXGqKk4
# 19                                      Carry Me Away  2LqV8nQW8XxF0oCBdvDIv8
# 11                                          Boyfriend  59CfNbkERJ3NoTXDvoURjj
# 20        Knife Talk (with 21 Savage ft. Project Pat)  2BcMwX1MPV6ZHP4tUT9uq6
# 6                                           September  2grjqo0Frpf2okIBiifQKs
# 28                                   Gymnopédie No. 1  5NGtFXVpXSvwunEIGeviY3
# 8                                             At Last  4Hhv2vrOTy89HFRcjU3QOx
# 26                                               Lost  3GZD6HmiNUhxXYf8Gch723
# 36                                               Lost  3GZD6HmiNUhxXYf8Gch723
# 43                                               Lost  3GZD6HmiNUhxXYf8Gch723
# 24                                            abcdefu  4fouWK6XVHhzl78KzQ1UjL
# 32                        pushin P (feat. Young Thug)  3XOalgusokruzA5ZBA2Qcb
# 2                                     Cornfield Chase  6pWgRkpqVfxnj3WuIcJ7WP
# 33                       Oceans (Where Feet May Fail)  5Mw9bXG1dLNhbjofkVS2oR
# 35                              What A Beautiful Name  4KLj9QjEhJl2WU50mxRF9Z
# 31                            AmeriKKKa's Most Wanted  2mYnMZOESVQeUcbvxR1lYi
# 21  Enemy (with JID) - from the series Arcane Leag...  1r9xUipOqoNwggBpENDsvJ
# 58                             The Arts and the Hours  1G3QPQkoXvpChjNUhd6Tfs
# 29  Cello Suite No. 1 in G Major, BWV 1007: I. Pré...  61dYvvfIRtIDFuqZypPAta
# 7                                          Yesterdays  78MhZkCx2DRoJ5OSICn2K6
# 56                                           Buy Dirt  69AIpwGNLxr4qS1X5ynx60
# 57                                    You Raise Me Up  4TbNLKRLKlxZDlS0pu7Lsy
# 18                                      Super Gremlin  4A8cWXxKfIL3lAyUDzXbCF
# 30                                      Super Gremlin  4A8cWXxKfIL3lAyUDzXbCF
# 15                                   The Night We Met  0QZ5yyl6B6utIWkxeBDxQN
# 27                                         Experience  1BncfTJAWxrsxyT9culBrj
# 1                                          The Batman  1NkI8DtCnjcWVCVLF0gB71
# 54                                      Wasted On You  3cBsEDNhFI9E82vPj3kvi3
# 55                                    Whiskey Glasses  6foY66mWZN0pSRjZ408c00
# 42                                           I Hate U  5dXWFMwD7I7zXsInONVl0H
# 12                                Bang Bang Bang Bang  2qLSXZuIHMsKydCEFDchc3
# 48                                           Santeria  2hnMS47jN0etwvFPzYk11f
# 50                                         What I Got  3B4q6KbHbGV51HO3GznBFF
# 47  Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)  4gzsuuZypVbxs0Af1LSZyB
# 17                                            Ophelia  3d8y0t70g7hw2FOWl9Z4Fm
# 25                                    Sweater Weather  2QjOHCTQ1Jl3zawyYOpxh6
# 49                           You're Gonna Go Far, Kid  6TfBA04WJ3X1d1wXhaCFVT
# 3                                       I Love You So  4SqWKzw0CbA05TGszDgMlc
# 44                                    Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 40                                  Seven Nation Army  3dPQuX8Gs42Y7b454ybpMR
# 0                                         Fallen Down  1jDMi92a9zNQuPD3uPMkla
# 16                                            Riptide  3JvrhDOgAt6p7K8mDyZwRd
# 22                                    Say It Ain't So  6VoIBz0VhCyz7OdEoRYDiA
# 4                                              YKWIM?  2vWBUC9djv6BtiGlmKiQaH
#
#     popularity                                         album_name  \
# 37          95                                         Easy On Me
# 38          92                                                 30
# 59          69                               Bocelli (Remastered)
# 5           86       Favourite Worst Nightmare (Standard Version)
# 23          86       Favourite Worst Nightmare (Standard Version)
# 46          95                                           Yonaguni
# 45          98                                             MAMIII
# 53          98                                             MAMIII
# 39          83                                         Melophobia
# 41          80                                         Melophobia
# 34          73                                      Reckless Love
# 14          86                                             Encore
# 13          80                                      U Are My High
# 10          94                                         Planet Her
# 52          94                                         Planet Her
# 9           97                                         Planet Her
# 51          97                                         Planet Her
# 19           2                                      Carry Me Away
# 11          96                                          Boyfriend
# 20          90                                Certified Lover Boy
# 6           85              The Best Of Earth, Wind & Fire Vol. 1
# 28          74                               Erik Satie & Friends
# 8           79                                           At Last!
# 26          91                                     channel ORANGE
# 36          91                                     channel ORANGE
# 43          91                                     channel ORANGE
# 24         100                                            abcdefu
# 32          93                                            DS4EVER
# 2           78  Interstellar (Original Motion Picture Soundtra...
# 33          71                              Zion (Deluxe Edition)
# 35          68                              What A Beautiful Name
# 31          53                            AmeriKKKa's Most Wanted
# 21          98  Enemy (with JID) [from the series Arcane Leagu...
# 58          65           Rameau, Ólafsson: The Arts and the Hours
# 29          67      Bach: Unaccompanied Cello Suites (Remastered)
# 7           21                                     Johnny Griffin
# 56          84                                           Buy Dirt
# 57          60                                             Closer
# 18          90  Sniper Gang Presents Syko Bob & Snapkatt: Nigh...
# 30          90  Sniper Gang Presents Syko Bob & Snapkatt: Nigh...
# 15          81                                     Strange Trails
# 27          83                                    In A Time Lapse
# 1           74    The Batman (Original Motion Picture Soundtrack)
# 54          83                        Dangerous: The Double Album
# 55          83                                       If I Know Me
# 42          89                                           I Hate U
# 12          74               Ribbed Music For The Numb Generation
# 48          81                                            Sublime
# 50          77                                            Sublime
# 47          95  Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)
# 17          80                                          Cleopatra
# 25          94                                        I Love You.
# 49          83                      Rise And Fall, Rage And Grace
# 3           96                                      I Love You So
# 44          95                                        After Hours
# 40          87                                           Elephant
# 0           77                               UNDERTALE Soundtrack
# 16          83             Dream Your Life Away (Special Edition)
# 22          79                                             Weezer
# 4           88                                            Bipolar
#
#                   album_id release_date
# 37  224jZ4sUX7OhAuMwaxp86S   2021-10-14
# 38  21jF5jlMtzo94wbxmJ18aa   2021-11-19
# 59  3uARqNN4bYqts3Ltg5Jku3   1995-01-01
# 5   6rsQnwaoJHxXJRCDBPkBRw   2007-04-24
# 23  6rsQnwaoJHxXJRCDBPkBRw   2007-04-24
# 46  6VSOIs13DaSG2IPilNviX5   2021-06-04
# 45  6GHUywBU0u92lg0Dhrt40R   2022-02-10
# 53  6GHUywBU0u92lg0Dhrt40R   2022-02-10
# 39  4EK8gtQfdVsmDTji7gBFlz   2013-10-08
# 41  4EK8gtQfdVsmDTji7gBFlz   2013-10-08
# 34  63fUIyRGFTFdVlDMTT5tLB   2018-01-26
# 14  1kTlYbs28MXw7hwO0NLYif   2004-11-12
# 13  0LMzMzG385642dtYwsVLkq   2021-07-28
# 10  1nAQbHeOWTfQzbOoFrvndW   2021-06-25
# 52  1nAQbHeOWTfQzbOoFrvndW   2021-06-25
# 9   1nAQbHeOWTfQzbOoFrvndW   2021-06-25
# 51  1nAQbHeOWTfQzbOoFrvndW   2021-06-25
# 19  3dlqG3m3IlYnsISyOLygAE   2022-02-27
# 11  4jUfPmvZGiRRJwULbfk1dc   2022-02-11
# 20  3SpBlxme9WbeQdI9kx7KAV   2021-09-03
# 6   2FW0uQ4WL25umm5p2VrZO7   1978-11-23
# 28  32kkHw8GnItrzLQ1qwupbJ         1949
# 8   3arNdjotCvtiiLFfjKngMc   2015-05-26
# 26  392p3shh2jkxUxY2VHvlH8   2012-07-10
# 36  392p3shh2jkxUxY2VHvlH8   2012-07-10
# 43  392p3shh2jkxUxY2VHvlH8   2012-07-10
# 24  6tUQPKlpR4x1gjrXTtOImI   2021-08-13
# 32  02uWB8Kekadkl3yGBoOOcx   2022-01-07
# 2   3B61kSKTxlY36cYgzvf3cP   2014-11-18
# 33  3A24aBx6jZCAgovIbZUubC   2013-02-26
# 35  7m2VtB9IdKJ0WZmnuSB5Q2   2017-01-06
# 31  3AI5kAUjgNtZBwFRi6opDc   1990-03-16
# 21  1bTgKomQYSkKYPD9UI9W4b   2021-10-28
# 58  4omnRCjOvnHa3ETQlqZpd1   2020-03-06
# 29  2OpnKgmVYPEN2GldgBponI         1983
# 7   1rq5uGDMH0yigfmK4djuG4   1956-01-01
# 56  2y9DFhTWC7QQJMvygK0TzO   2021-05-21
# 57  0rSLgV8p5FzfnqlEk4GzxE   2016-07-29
# 18  0kxA9Bc8pamypR5GYXmeti   2021-10-30
# 30  0kxA9Bc8pamypR5GYXmeti   2021-10-30
# 15  3yoNZlqerJnsnMN5EDwwBS   2015-04-07
# 27  3uJ6D2WOPdjwJ0SrsH9EiG   2013-01-01
# 1   18nTX27XXEYARGmWMTgD19   2022-02-24
# 54  6JlCkqkqobGirPsaleJpFr   2021-01-08
# 55  1IR2nlwX6YVTXXeu2qzoWO   2018-04-27
# 42  1hJUh5y1ggqqGsCivnRmHw   2021-12-03
# 12  6DK0TneKMKj64I93VCG1bW   2007-09-24
# 48  14eK347GdWO4mBBx78tsut   1996-07-30
# 50  14eK347GdWO4mBBx78tsut   1996-07-30
# 47  4589OIFRZp41qbsp7TWFCx   2021-10-05
# 17  2zbTrm2pIAErzFSopinkbN   2016-04-08
# 25  4xkM0BwLM9H2IUcbYzpcBI   2013-04-19
# 49  67v63ubEsvDUQkYMzI7A9t   2008-06-17
# 3   7ucm85tRsWk6EyVHaYAxe9   2014-11-28
# 44  4yP0hdKOZPNshxUOjY0cZj   2020-03-20
# 40  6D9urpsOWWKtYvF6PaorGE   2003-04-01
# 0   2M2Ae2SvZe3fmzUtlVOV5Z   2015-09-15
# 16  5S9b8euumqMhQbMk0zzQdH   2014-09-09
# 22  1xpGyKyV26uPstk1Elgp9Q   1994-05-10
# 4   60jUlxAOAcsiQUEW0XLroT   2019-05-31

# %%
df_tracks.shape
# Out:
# (60, 10)

# %%
df_tracks.drop_duplicates(inplace=True)
df_tracks.shape
# Out:
# (60, 10)

# %% [markdown]
# #### Checking for track or artist duplicates

# %%
grouped = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
f'This df_tracks has {grouped[grouped > 1].count()} duplicates to be addressed.'
# Out:
# 'This df_tracks has 6 duplicates to be addressed.'

# %%
grouped
# Out:
# artist_name            track_name
# Adele                  Easy On Me                                                     1
#                        Oh My God                                                      1
# Andrea Bocelli         Con te partirò                                                 1
# Arctic Monkeys         505                                                            2
# Bad Bunny              Yonaguni                                                       1
# Becky G                MAMIII                                                         2
# Cage The Elephant      Cigarette Daydreams                                            1
#                        Come a Little Closer                                           1
# Cory Asbury            Reckless Love                                                  1
# DJ Snake               Let Me Love You                                                1
#                        U Are My High                                                  1
# Doja Cat               Need to Know                                                   2
#                        Woman                                                          2
# Dolphin                Carry Me Away                                                  1
# Dove Cameron           Boyfriend                                                      1
# Drake                  Knife Talk (with 21 Savage ft. Project Pat)                    1
# Earth, Wind & Fire     September                                                      1
# Erik Satie             Gymnopédie No. 1                                               1
# Etta James             At Last                                                        1
# Frank Ocean            Lost                                                           3
# GAYLE                  abcdefu                                                        1
# Gunna                  pushin P (feat. Young Thug)                                    1
# Hans Zimmer            Cornfield Chase                                                1
# Hillsong UNITED        Oceans (Where Feet May Fail)                                   1
# Hillsong Worship       What A Beautiful Name                                          1
# Ice Cube               AmeriKKKa's Most Wanted                                        1
# Imagine Dragons        Enemy (with JID) - from the series Arcane League of Legends    1
# Jean-Philippe Rameau   The Arts and the Hours                                         1
# Johann Sebastian Bach  Cello Suite No. 1 in G Major, BWV 1007: I. Prélude             1
# Johnny Griffin         Yesterdays                                                     1
# Jordan Davis           Buy Dirt                                                       1
# Josh Groban            You Raise Me Up                                                1
# Kodak Black            Super Gremlin                                                  2
# Lord Huron             The Night We Met                                               1
# Ludovico Einaudi       Experience                                                     1
# Michael Giacchino      The Batman                                                     1
# Morgan Wallen          Wasted On You                                                  1
#                        Whiskey Glasses                                                1
# SZA                    I Hate U                                                       1
# Sohodolls              Bang Bang Bang Bang                                            1
# Sublime                Santeria                                                       1
#                        What I Got                                                     1
# Tainy                  Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)              1
# The Lumineers          Ophelia                                                        1
# The Neighbourhood      Sweater Weather                                                1
# The Offspring          You're Gonna Go Far, Kid                                       1
# The Walters            I Love You So                                                  1
# The Weeknd             Blinding Lights                                                1
# The White Stripes      Seven Nation Army                                              1
# Toby Fox               Fallen Down                                                    1
# Vance Joy              Riptide                                                        1
# Weezer                 Say It Ain't So                                                1
# Yot Club               YKWIM?                                                         1
# dtype: int64

# %% [markdown]
# Duplicates will probably occur frequently since its an issue with how Spotify classifies multiple genres per artist and how our provided genre parameters are purposely broad. E.g. Earth, Wind & Fire is classified as Jazz and Soul (among other things), so may appear in our dataset multiple times if the dataset is large enough.

# %% [markdown]
# #### Drop duplicates

# %%
print(f'We start with a DataFrame with shape {df_tracks.shape}.')

# %%
df_tracks.drop_duplicates(subset=['artist_name','track_name'], inplace=True)

# %%
grouped_after_drop = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
print(f'This df_tracks has {grouped_after_drop[grouped_after_drop > 1].count()} duplicates to be addressed.')

# %%
print(f'DataFrame has shape {df_tracks.shape} after addressing any duplicates.')

# %% [markdown]
# ## Get the audio features per track

# %%
# The audio features search has a limit of 100 track IDs that can be submitted per query.
start = timeit.default_timer()

# empty list for rows, define the batchsize as the limit per query, zeroing the None_counter
rows = []
batchsize = 100
None_counter = 0

for i in range(0, len(df_tracks['track_id']), batchsize):
    batch = df_tracks['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter +1
        else:
            rows.append(t)

print(f'Number of tracks where no audio features were available:', None_counter)

stop = timeit.default_timer()
print(f'This took {stop - start} seconds to complete.')

# %% [markdown]
# #### Inspect the audio features dataset

# %%
print(f'Number of elements in audio features dataset: {len(rows)}')

# %%
df_audio_features = pd.DataFrame.from_dict(rows,orient='columns')
df_audio_features.head()

# %%
df_audio_features[df_audio_features.duplicated(subset=['id'],keep=False)]

# %%
df_audio_features.columns

# %%
df_tracks.columns

# %% [markdown]
# #### Transform audio features DataFrame

# %%
df_audio_features.drop(['track_href','analysis_url','uri','type'], axis=1, inplace=True)
df_audio_features.rename(columns={'id':'track_id'}, inplace=True)

# %% [markdown]
# ### Generate the dataframes in the format of tables in ERD

# %%
df_all = pd.merge(df_tracks, df_audio_features, on='track_id', how='inner')
df_all

# %%
df_all.shape

# %%
df_all.columns

# %%
artist_data = df_all[['artist_name','artist_id','followers']]
album_data = df_all[['album_name','album_id','release_date']]
track_features = df_all[[
    'track_name',
    'track_id',
    'artist_id',
    'album_id',
    'acousticness',
    'danceability',
    'duration_ms',
    'energy',
    'genre',
    'instrumentalness',
    'key',
    'liveness',
    'loudness',
    'mode',
    'popularity',
    'speechiness',
    'tempo',
    'time_signature',
    'valence'
]]

# %%
print(f'DataFrames artist_data has shape {artist_data.shape}, album_data has shape {album_data.shape} and track_features has shape {track_features.shape}')

# %%
# # Imports
# from sqlalchemy import create_engine
# import psycopg2 
# from config import db_password

# # Create connection to database (endpoint to be decided)
# db_string = f"postgresql://postgres:{db_password}@{endpoint}"

# # instantiate engine
# engine = create_engine(db_string)

# artist_data.to_sql(name='artist_data', con=engine, if_exists='replace', index=False)
# album_data.to_sql(name='album_data', con=engine, if_exists='replace', index=False)
# track_features.to_sql(name='track_features', con=engine, if_exists='replace', index=False)
